# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Convolution2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Flatten
import cv2
import numpy as np
import glob
import os
from random import shuffle

# %%
from tensorflow import keras

# %%
import tensorflow as tf
print(tf.test.gpu_device_name())

# %%
X_train=[]
X_test=[]
Y_test=[]
Y_train=[]
dataTr=[]
for filename in glob.glob(os.path.join('D:/UMSA/TESIS/Tesis de grado/data/entrenamiento/Melanoma_escalado','*.jpg')):
    dataTr.append([1,cv2.imread(filename)])
for filename in glob.glob(os.path.join('D:/UMSA/TESIS/Tesis de grado/data/entrenamiento/Carcinoma_escalado','*.jpg')):
    dataTr.append([0,cv2.imread(filename)])

# %%
dataTe=[]
for filename in glob.glob(os.path.join('D:/UMSA/TESIS/Tesis de grado/data/prueba/melanoma_escalado','*.jpg')):
    dataTe.append([1,cv2.imread(filename)])
for filename in glob.glob(os.path.join('D:/UMSA/TESIS/Tesis de grado/data/prueba/carcinoma_escalado','*.jpg')):
    dataTe.append([0,cv2.imread(filename)])

# %%
def particion(datos):
    imagenes=[]
    etiquetas=[]
    for i,j in datos:
        imagenes.append(j)
        etiquetas.append(i)
    imagenes=np.array(imagenes)
    etiquetas=np.array(etiquetas)
    return (imagenes,etiquetas)

# %%
shuffle(dataTr)
print("en total tenemos: "+str(len(dataTr))+ " imagenes dentro de la carpeta train")
shuffle(dataTe)
print("en total tenemos: "+str(len(dataTe))+ " imagenes dentro de la carpeta test")
# Out:
# en total tenemos: 12279 imagenes dentro de la carpeta train
# en total tenemos: 5261 imagenes dentro de la carpeta test

# %%
porcion1=dataTr[0:12000]
porcion2=dataTe[0:5000]
print("para entrenamiento tendremos: "+str(len(porcion1))+ " imagenes de la carpeta de train")
print("para prueba tendremos: "+str(len(porcion2))+ " imagenes de la carpeta de test")
# Out:
# para entrenamiento tendremos: 12000 imagenes de la carpeta de train
# para prueba tendremos: 5000 imagenes de la carpeta de test

# %%
x_e,y_e=particion(porcion1)
x_p,y_p=particion(porcion2)

# %%
def validacion(x_e,y_e,x_p,y_p,modelo1,epocas):
    entre=modelo1.fit(x_e,y_e,batch_size=32,epochs=epocas,validation_data=(x_p,y_p))
    a=modelo1.evaluate(x_p,y_p)
    return a[1]

# %%
def evaluacion(modelo1,porcentaje,nombre,v1,v2):
    prediccion=0
    epocas=1
    while(True):
        if prediccion < 81:
            prediccion=(validacion(x_e,y_e,x_p,y_p,modelo1,1))*100
            epocas +=1
            v1.append(epocas-1)
            v2.append(prediccion)
        else:
            modelo1.save("D:/UMSA/Documentos/CNN cancer de piel/MODELOS/17000_2/modelo")
            if prediccion > porcentaje:
                print("==> Para el metodo "+nombre+" se utilizo: "+str(epocas-1)+" epocas para llegar a mas del "+str(porcentaje)+"% de acertividad")
                break

# %%
modelo=Sequential()
modelo.add(Convolution2D(8,(3,3),input_shape=(224,224,3),activation='relu'))
modelo.add(Convolution2D(16,(3,3),activation='relu'))
modelo.add(MaxPooling2D(pool_size=((2,2))))
modelo.add(Flatten())
modelo.add(Dense(128,activation='relu'))
modelo.add(Dense(70,activation='relu'))
modelo.add(Dense(1,activation='sigmoid'))
modelo.summary()
# Out:
# WARNING:tensorflow:From C:\Users\Desktop\.conda\envs\tesis\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 222, 222, 8)       224
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 220, 220, 16)      1168
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 110, 110, 16)      0
# _________________________________________________________________
# flatten (Flatten)            (None, 193600)            0
# _________________________________________________________________
# dense (Dense)                (None, 128)               24780928
# _________________________________________________________________
# dense_1 (Dense)              (None, 70)                9030
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 71
# =================================================================
# Total params: 24,791,421
# Trainable params: 24,791,421
# Non-trainable params: 0
# _________________________________________________________________

# %%
modelo_adam = keras.optimizers.Adam(learning_rate=0.0008)
modelo.compile(optimizer=modelo_adam,loss='binary_crossentropy',metrics=['accuracy'])
v_eA=[]
v_aA=[]
evaluacion(modelo,85,"ADAM",v_eA,v_aA)
# Out:
# WARNING:tensorflow:From C:\Users\Desktop\.conda\envs\tesis\lib\site-packages\tensorflow_core\python\ops\nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 131s 11ms/sample - loss: 9.1083 - acc: 0.6492 - val_loss: 0.6020 - val_acc: 0.6980
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 0.6020 - acc: 0.6980
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 131s 11ms/sample - loss: 0.4293 - acc: 0.8170 - val_loss: 0.6327 - val_acc: 0.7312
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 0.6327 - acc: 0.7312
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 131s 11ms/sample - loss: 0.2787 - acc: 0.9031 - val_loss: 0.7792 - val_acc: 0.7350
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 0.7792 - acc: 0.7350
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 131s 11ms/sample - loss: 0.1323 - acc: 0.9578 - val_loss: 1.0484 - val_acc: 0.7314
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 1.0484 - acc: 0.7314
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 128s 11ms/sample - loss: 0.0998 - acc: 0.9697 - val_loss: 1.1343 - val_acc: 0.7460
# 5000/5000 [==============================] - 8s 2ms/sample - loss: 1.1343 - acc: 0.7460
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 128s 11ms/sample - loss: 0.0634 - acc: 0.9827 - val_loss: 1.1935 - val_acc: 0.7336
# 5000/5000 [==============================] - 8s 2ms/sample - loss: 1.1935 - acc: 0.7336
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 128s 11ms/sample - loss: 0.0578 - acc: 0.9844 - val_loss: 1.5488 - val_acc: 0.7190
# 5000/5000 [==============================] - 8s 2ms/sample - loss: 1.5488 - acc: 0.7190
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 128s 11ms/sample - loss: 0.0945 - acc: 0.9738 - val_loss: 1.3497 - val_acc: 0.7410
# 5000/5000 [==============================] - 8s 2ms/sample - loss: 1.3497 - acc: 0.7410
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 128s 11ms/sample - loss: 0.0854 - acc: 0.9803 - val_loss: 1.3486 - val_acc: 0.7152
# 5000/5000 [==============================] - 8s 2ms/sample - loss: 1.3486 - acc: 0.7152
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 128s 11ms/sample - loss: 0.0362 - acc: 0.9905 - val_loss: 1.6508 - val_acc: 0.7610
# 5000/5000 [==============================] - 8s 2ms/sample - loss: 1.6508 - acc: 0.7610
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 128s 11ms/sample - loss: 0.0482 - acc: 0.9866 - val_loss: 1.6250 - val_acc: 0.7642
# 5000/5000 [==============================] - 8s 2ms/sample - loss: 1.6250 - acc: 0.7642
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 128s 11ms/sample - loss: 0.1246 - acc: 0.9628 - val_loss: 1.2349 - val_acc: 0.7094
# 5000/5000 [==============================] - 8s 2ms/sample - loss: 1.2349 - acc: 0.7094
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 128s 11ms/sample - loss: 0.1157 - acc: 0.9617 - val_loss: 1.4227 - val_acc: 0.7196
# 5000/5000 [==============================] - 8s 2ms/sample - loss: 1.4227 - acc: 0.7196
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 130s 11ms/sample - loss: 0.0924 - acc: 0.9709 - val_loss: 1.4095 - val_acc: 0.7060
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 1.4095 - acc: 0.7060
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 133s 11ms/sample - loss: 0.0759 - acc: 0.9778 - val_loss: 1.6230 - val_acc: 0.7288
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 1.6230 - acc: 0.7288
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 133s 11ms/sample - loss: 0.0648 - acc: 0.9841 - val_loss: 1.5750 - val_acc: 0.7236
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 1.5750 - acc: 0.7236
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 133s 11ms/sample - loss: 0.0395 - acc: 0.9887 - val_loss: 1.6220 - val_acc: 0.7264
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 1.6220 - acc: 0.7264
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 0.0404 - acc: 0.9886 - val_loss: 1.9904 - val_acc: 0.7318
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 1.9904 - acc: 0.7318
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 0.0513 - acc: 0.9858 - val_loss: 1.9192 - val_acc: 0.7366
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 1.9192 - acc: 0.7366
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 0.0205 - acc: 0.9948 - val_loss: 1.8420 - val_acc: 0.7170
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 1.8420 - acc: 0.7170
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 131s 11ms/sample - loss: 0.0218 - acc: 0.9932 - val_loss: 2.0823 - val_acc: 0.7278
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 2.0823 - acc: 0.7278
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 0.0718 - acc: 0.9823 - val_loss: 2.2359 - val_acc: 0.7184
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 2.2359 - acc: 0.7184
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 131s 11ms/sample - loss: 0.1494 - acc: 0.9638 - val_loss: 1.6504 - val_acc: 0.7142
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 1.6504 - acc: 0.7142
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 131s 11ms/sample - loss: 0.0797 - acc: 0.9812 - val_loss: 1.6487 - val_acc: 0.6978
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 1.6487 - acc: 0.6978
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 131s 11ms/sample - loss: 0.0762 - acc: 0.9827 - val_loss: 1.6753 - val_acc: 0.7532
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 1.6753 - acc: 0.7532
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 131s 11ms/sample - loss: 0.0153 - acc: 0.9962 - val_loss: 1.9209 - val_acc: 0.7342
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 1.9209 - acc: 0.7342
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 131s 11ms/sample - loss: 0.0088 - acc: 0.9983 - val_loss: 1.9093 - val_acc: 0.7116
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 1.9093 - acc: 0.7116
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 0.0486 - acc: 0.9839 - val_loss: 2.0669 - val_acc: 0.7024
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 2.0669 - acc: 0.7024
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 0.0491 - acc: 0.9868 - val_loss: 2.1969 - val_acc: 0.7322
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 2.1969 - acc: 0.7322
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 0.0093 - acc: 0.9976 - val_loss: 2.9602 - val_acc: 0.7094
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 2.9602 - acc: 0.7094
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 0.0278 - acc: 0.9939 - val_loss: 2.1611 - val_acc: 0.7404
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 2.1611 - acc: 0.7404
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 0.0031 - acc: 0.9992 - val_loss: 2.4609 - val_acc: 0.7438
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 2.4609 - acc: 0.7438
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 7.3741e-04 - acc: 0.9998 - val_loss: 2.7965 - val_acc: 0.7562
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 2.7965 - acc: 0.7562
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 0.0010 - acc: 0.9998 - val_loss: 2.7266 - val_acc: 0.7492
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 2.7266 - acc: 0.7492
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 131s 11ms/sample - loss: 1.1135e-04 - acc: 1.0000 - val_loss: 2.7991 - val_acc: 0.7490
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 2.7991 - acc: 0.7490
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 6.2600e-05 - acc: 1.0000 - val_loss: 2.8112 - val_acc: 0.7520
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 2.8112 - acc: 0.7520
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 4.1736e-05 - acc: 1.0000 - val_loss: 2.8433 - val_acc: 0.7534
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 2.8433 - acc: 0.7534
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 2.9412e-05 - acc: 1.0000 - val_loss: 2.8720 - val_acc: 0.7532
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 2.8720 - acc: 0.7532
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 2.1063e-05 - acc: 1.0000 - val_loss: 2.8976 - val_acc: 0.7552
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 2.8976 - acc: 0.7552
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 1.5518e-05 - acc: 1.0000 - val_loss: 2.9294 - val_acc: 0.7552
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 2.9294 - acc: 0.7552
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 1.1552e-05 - acc: 1.0000 - val_loss: 2.9596 - val_acc: 0.7576
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 2.9596 - acc: 0.7576
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 8.7411e-06 - acc: 1.0000 - val_loss: 2.9840 - val_acc: 0.7582
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 2.9840 - acc: 0.7582
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 6.6450e-06 - acc: 1.0000 - val_loss: 3.0098 - val_acc: 0.7596
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 3.0098 - acc: 0.7596
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 5.0958e-06 - acc: 1.0000 - val_loss: 3.0398 - val_acc: 0.7614
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 3.0398 - acc: 0.7614
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 3.9448e-06 - acc: 1.0000 - val_loss: 3.0656 - val_acc: 0.7614
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 3.0656 - acc: 0.7614
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 3.0609e-06 - acc: 1.0000 - val_loss: 3.0917 - val_acc: 0.7628
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 3.0917 - acc: 0.7628
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 2.3852e-06 - acc: 1.0000 - val_loss: 3.1168 - val_acc: 0.7648
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 3.1168 - acc: 0.7648
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 1.8673e-06 - acc: 1.0000 - val_loss: 3.1449 - val_acc: 0.7656
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 3.1449 - acc: 0.7656
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 1.4679e-06 - acc: 1.0000 - val_loss: 3.1690 - val_acc: 0.7668
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 3.1690 - acc: 0.7668
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 1.1556e-06 - acc: 1.0000 - val_loss: 3.1927 - val_acc: 0.7668
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 3.1927 - acc: 0.7668
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 9.1288e-07 - acc: 1.0000 - val_loss: 3.2187 - val_acc: 0.7670
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 3.2187 - acc: 0.7670
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 7.2558e-07 - acc: 1.0000 - val_loss: 3.2427 - val_acc: 0.7674
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 3.2427 - acc: 0.7674
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 5.7898e-07 - acc: 1.0000 - val_loss: 3.2649 - val_acc: 0.7678
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 3.2649 - acc: 0.7678
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 4.6248e-07 - acc: 1.0000 - val_loss: 3.2913 - val_acc: 0.7688
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 3.2913 - acc: 0.7688
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 3.7014e-07 - acc: 1.0000 - val_loss: 3.3149 - val_acc: 0.7686
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 3.3149 - acc: 0.7686
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 2.9753e-07 - acc: 1.0000 - val_loss: 3.3375 - val_acc: 0.7696
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 3.3375 - acc: 0.7696
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 2.4031e-07 - acc: 1.0000 - val_loss: 3.3612 - val_acc: 0.7700
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 3.3612 - acc: 0.7700
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 1.9442e-07 - acc: 1.0000 - val_loss: 3.3840 - val_acc: 0.7712
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 3.3840 - acc: 0.7712
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 1.5730e-07 - acc: 1.0000 - val_loss: 3.4082 - val_acc: 0.7708
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 3.4082 - acc: 0.7708
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 1.2810e-07 - acc: 1.0000 - val_loss: 3.4314 - val_acc: 0.7708
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 3.4314 - acc: 0.7708
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 1.0449e-07 - acc: 1.0000 - val_loss: 3.4542 - val_acc: 0.7710
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 3.4542 - acc: 0.7710
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 8.5573e-08 - acc: 1.0000 - val_loss: 3.4748 - val_acc: 0.7708
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 3.4748 - acc: 0.7708
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 7.0303e-08 - acc: 1.0000 - val_loss: 3.4986 - val_acc: 0.7716
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 3.4986 - acc: 0.7716
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 5.7835e-08 - acc: 1.0000 - val_loss: 3.5223 - val_acc: 0.7720
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 3.5223 - acc: 0.7720
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 4.7527e-08 - acc: 1.0000 - val_loss: 3.5446 - val_acc: 0.7714
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 3.5446 - acc: 0.7714
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 3.9279e-08 - acc: 1.0000 - val_loss: 3.5683 - val_acc: 0.7716
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 3.5683 - acc: 0.7716
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 3.2674e-08 - acc: 1.0000 - val_loss: 3.5900 - val_acc: 0.7712
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 3.5900 - acc: 0.7712
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 2.7226e-08 - acc: 1.0000 - val_loss: 3.6138 - val_acc: 0.7706
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 3.6138 - acc: 0.7706
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 2.2795e-08 - acc: 1.0000 - val_loss: 3.6371 - val_acc: 0.7704
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 3.6371 - acc: 0.7704
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 133s 11ms/sample - loss: 1.9167e-08 - acc: 1.0000 - val_loss: 3.6585 - val_acc: 0.7702
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 3.6585 - acc: 0.7702
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 1.6158e-08 - acc: 1.0000 - val_loss: 3.6780 - val_acc: 0.7708
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 3.6780 - acc: 0.7708
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 1.3686e-08 - acc: 1.0000 - val_loss: 3.6992 - val_acc: 0.7712
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 3.6992 - acc: 0.7712
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 1.1646e-08 - acc: 1.0000 - val_loss: 3.7213 - val_acc: 0.7708
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 3.7213 - acc: 0.7708
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 9.9421e-09 - acc: 1.0000 - val_loss: 3.7443 - val_acc: 0.7706
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 3.7443 - acc: 0.7706
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 8.5423e-09 - acc: 1.0000 - val_loss: 3.7618 - val_acc: 0.7710
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 3.7618 - acc: 0.7710
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 7.3458e-09 - acc: 1.0000 - val_loss: 3.7858 - val_acc: 0.7702
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 3.7858 - acc: 0.7702
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 131s 11ms/sample - loss: 6.3820e-09 - acc: 1.0000 - val_loss: 3.8057 - val_acc: 0.7702
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 3.8057 - acc: 0.7702
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 131s 11ms/sample - loss: 5.5358e-09 - acc: 1.0000 - val_loss: 3.8262 - val_acc: 0.7702
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 3.8262 - acc: 0.7702
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 4.8280e-09 - acc: 1.0000 - val_loss: 3.8445 - val_acc: 0.7714
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 3.8445 - acc: 0.7714
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 4.2474e-09 - acc: 1.0000 - val_loss: 3.8627 - val_acc: 0.7718
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 3.8627 - acc: 0.7718
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 3.7373e-09 - acc: 1.0000 - val_loss: 3.8797 - val_acc: 0.7714
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 3.8797 - acc: 0.7714
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 131s 11ms/sample - loss: 3.2975e-09 - acc: 1.0000 - val_loss: 3.8989 - val_acc: 0.7710
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 3.8989 - acc: 0.7710
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 131s 11ms/sample - loss: 2.9380e-09 - acc: 1.0000 - val_loss: 3.9147 - val_acc: 0.7710
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 3.9147 - acc: 0.7710
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 2.6168e-09 - acc: 1.0000 - val_loss: 3.9302 - val_acc: 0.7716
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 3.9302 - acc: 0.7716
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 131s 11ms/sample - loss: 2.3425e-09 - acc: 1.0000 - val_loss: 3.9507 - val_acc: 0.7712
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 3.9507 - acc: 0.7712
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 2.1010e-09 - acc: 1.0000 - val_loss: 3.9655 - val_acc: 0.7712
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 3.9655 - acc: 0.7712
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 1.8931e-09 - acc: 1.0000 - val_loss: 3.9858 - val_acc: 0.7716
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 3.9858 - acc: 0.7716
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 1.7062e-09 - acc: 1.0000 - val_loss: 4.0054 - val_acc: 0.7718
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 4.0054 - acc: 0.7718
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 131s 11ms/sample - loss: 1.5487e-09 - acc: 1.0000 - val_loss: 4.0273 - val_acc: 0.7716
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 4.0273 - acc: 0.7716
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 1.4088e-09 - acc: 1.0000 - val_loss: 4.0488 - val_acc: 0.7714
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 4.0488 - acc: 0.7714
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 1.2787e-09 - acc: 1.0000 - val_loss: 4.0630 - val_acc: 0.7718
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 4.0630 - acc: 0.7718
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 1.1796e-09 - acc: 1.0000 - val_loss: 4.0737 - val_acc: 0.7720
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 4.0737 - acc: 0.7720
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 131s 11ms/sample - loss: 1.0853e-09 - acc: 1.0000 - val_loss: 4.1007 - val_acc: 0.7716
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 4.1007 - acc: 0.7716
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 131s 11ms/sample - loss: 1.0206e-09 - acc: 1.0000 - val_loss: 4.1104 - val_acc: 0.7724
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 4.1104 - acc: 0.7724
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 9.2930e-10 - acc: 1.0000 - val_loss: 4.1262 - val_acc: 0.7720
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 4.1262 - acc: 0.7720
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 8.6820e-10 - acc: 1.0000 - val_loss: 4.1449 - val_acc: 0.7722
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 4.1449 - acc: 0.7722
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 8.2055e-10 - acc: 1.0000 - val_loss: 4.1592 - val_acc: 0.7714
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 4.1592 - acc: 0.7714
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 7.4245e-10 - acc: 1.0000 - val_loss: 4.1881 - val_acc: 0.7716
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 4.1881 - acc: 0.7716
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 131s 11ms/sample - loss: 7.0977e-10 - acc: 1.0000 - val_loss: 4.2156 - val_acc: 0.7704
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 4.2156 - acc: 0.7704
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 6.6484e-10 - acc: 1.0000 - val_loss: 4.2147 - val_acc: 0.7716
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 4.2147 - acc: 0.7716
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 132s 11ms/sample - loss: 6.2114e-10 - acc: 1.0000 - val_loss: 4.2438 - val_acc: 0.7714
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 4.2438 - acc: 0.7714
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 131s 11ms/sample - loss: 5.9384e-10 - acc: 1.0000 - val_loss: 4.2323 - val_acc: 0.7724
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 4.2323 - acc: 0.7724
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 131s 11ms/sample - loss: 5.7764e-10 - acc: 1.0000 - val_loss: 4.2535 - val_acc: 0.7716
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 4.2535 - acc: 0.7716
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 131s 11ms/sample - loss: 5.0612e-10 - acc: 1.0000 - val_loss: 4.3044 - val_acc: 0.7714
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 4.3044 - acc: 0.7714
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 131s 11ms/sample - loss: 0.9620 - acc: 0.8975 - val_loss: 0.9730 - val_acc: 0.6730
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 0.9730 - acc: 0.6730
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 131s 11ms/sample - loss: 0.5156 - acc: 0.7792 - val_loss: 1.0772 - val_acc: 0.7016
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 1.0772 - acc: 0.7016
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 131s 11ms/sample - loss: 0.3007 - acc: 0.8740 - val_loss: 1.3308 - val_acc: 0.6582
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 1.3308 - acc: 0.6582
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 131s 11ms/sample - loss: 0.2503 - acc: 0.8925 - val_loss: 1.8760 - val_acc: 0.7122
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 1.8760 - acc: 0.7122
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 131s 11ms/sample - loss: 0.1831 - acc: 0.9299 - val_loss: 1.8481 - val_acc: 0.6980
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 1.8481 - acc: 0.6980
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 131s 11ms/sample - loss: 0.1727 - acc: 0.9331 - val_loss: 2.4840 - val_acc: 0.7016
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 2.4840 - acc: 0.7016
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 131s 11ms/sample - loss: 0.1141 - acc: 0.9548 - val_loss: 2.6994 - val_acc: 0.7112
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 2.6994 - acc: 0.7112
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 131s 11ms/sample - loss: 0.1096 - acc: 0.9603 - val_loss: 2.4856 - val_acc: 0.6956
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 2.4856 - acc: 0.6956
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 131s 11ms/sample - loss: 0.1017 - acc: 0.9611 - val_loss: 3.1116 - val_acc: 0.7008
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 3.1116 - acc: 0.7008
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 131s 11ms/sample - loss: 0.2317 - acc: 0.9238 - val_loss: 1.8778 - val_acc: 0.7078
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 1.8778 - acc: 0.7078
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 131s 11ms/sample - loss: 0.2061 - acc: 0.9266 - val_loss: 2.2677 - val_acc: 0.7034
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 2.2677 - acc: 0.7034
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 131s 11ms/sample - loss: 0.1107 - acc: 0.9654 - val_loss: 2.8355 - val_acc: 0.7170
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 2.8355 - acc: 0.7170
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 131s 11ms/sample - loss: 0.0621 - acc: 0.9774 - val_loss: 3.6780 - val_acc: 0.7206
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 3.6780 - acc: 0.7206
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 131s 11ms/sample - loss: 0.0603 - acc: 0.9791 - val_loss: 3.2296 - val_acc: 0.7216
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 3.2296 - acc: 0.7216
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 131s 11ms/sample - loss: 0.0902 - acc: 0.9697 - val_loss: 3.3881 - val_acc: 0.7082
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 3.3881 - acc: 0.7082
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 131s 11ms/sample - loss: 0.0420 - acc: 0.9868 - val_loss: 3.7343 - val_acc: 0.7188
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 3.7343 - acc: 0.7188
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 131s 11ms/sample - loss: 0.0769 - acc: 0.9769 - val_loss: 3.8972 - val_acc: 0.7334
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 3.8972 - acc: 0.7334
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 131s 11ms/sample - loss: 0.0882 - acc: 0.9706 - val_loss: 4.0175 - val_acc: 0.7106
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 4.0175 - acc: 0.7106
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 131s 11ms/sample - loss: 0.0599 - acc: 0.9810 - val_loss: 4.3297 - val_acc: 0.7130
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 4.3297 - acc: 0.7130
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 131s 11ms/sample - loss: 0.0845 - acc: 0.9785 - val_loss: 2.2293 - val_acc: 0.6630
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 2.2293 - acc: 0.6630
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 131s 11ms/sample - loss: 0.1503 - acc: 0.9497 - val_loss: 3.2663 - val_acc: 0.7152
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 3.2663 - acc: 0.7152
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 131s 11ms/sample - loss: 0.0458 - acc: 0.9878 - val_loss: 3.9647 - val_acc: 0.7240
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 3.9647 - acc: 0.7240
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 131s 11ms/sample - loss: 0.0212 - acc: 0.9929 - val_loss: 4.2182 - val_acc: 0.7232
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 4.2182 - acc: 0.7232
# Train on 12000 samples, validate on 5000 samples
# 12000/12000 [==============================] - 131s 11ms/sample - loss: 0.1026 - acc: 0.9690 - val_loss: 2.7142 - val_acc: 0.6798
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 2.7142 - acc: 0.6798
# Train on 12000 samples, validate on 5000 samples
#  9152/12000 [=====================>........] - ETA: 29s - loss: 0.0858 - acc: 0.9739

# %%
modelo.save("D:/UMSA/Documentos/CNN cancer de piel/MODELOS/17000_2/modelo")

# %%
modelo.save_weights("D:/UMSA/Documentos/CNN cancer de piel/PESOS/17000_2/modelo_pesos")

# %%
count=1
print("# de EPOCAS     Valor del Accuracy")
print("----------------------------------")
for i in v_aA:
    print("epoca ",count," => ",i)
    count +=1

# %%
# %matplotlib inline
import matplotlib.pyplot as mp

# %%
mp.plot(v_aA,v_eA, marker='o', linestyle=':', color='b', label = "ADAM")

#mp.xticks(np.arange(70,100,2))
#mp.yticks(np.arange(0,4,1))
mp.xlabel("porcentaje de asertividad")
mp.ylabel("Numero de epocas")
mp.legend(loc="upper left")
mp.title("Nivel de asertividad y epocas con 10000 imagenes")
mp.grid(True)
mp.show()

# %%
modelo_cargado=keras.models.load_model("D:/UMSA/Documentos/CNN cancer de piel/MODELOS/12500/modelo")

# %%
modelo_cargado.summary()

# %%
# %matplotlib inline
import matplotlib.pyplot as mp

# %%
mp.plot(v_aA,v_eA, marker='o', linestyle=':', color='b', label = "ADAM")

#mp.xticks(np.arange(70,100,2))
#mp.yticks(np.arange(0,4,1))
mp.xlabel("porcentaje de asertividad")
mp.ylabel("Numero de epocas")
mp.legend(loc="upper left")
mp.title("Nivel de asertividad y epocas con 17000 imagenes")
mp.grid(True)
mp.show()

# %%
lr_probs = modelo.predict_proba(x_p)
lr_probs = lr_probs[:, 0]
ns_probs = [0 for _ in range(len(y_p))]

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from matplotlib import pyplot

# %%
# Calculamos el AUC
ns_auc = roc_auc_score(y_p, ns_probs)
lr_auc = roc_auc_score(y_p, lr_probs)
# Imprimimos en pantalla
print('Sin entrenar: ROC AUC=%.3f' % (ns_auc))
print('Red Neuronal: ROC AUC=%.3f' % (lr_auc))

# %%
# Calculamos las curvas ROC
ns_fpr, ns_tpr, _ = roc_curve(y_p, ns_probs)
lr_fpr, lr_tpr, _ = roc_curve(y_p, lr_probs)
# Pintamos las curvas ROC
pyplot.plot(ns_fpr, ns_tpr, linestyle='--', label='Sin entrenar')
pyplot.plot(lr_fpr, lr_tpr, marker='.', label='Red Neuronal')
# Etiquetas de los ejes
pyplot.xlabel('Tasa de Falsos Positivos')
pyplot.ylabel('Tasa de Verdaderos Positivos')
pyplot.legend()
mp.grid(True)
pyplot.show()

# %%
lr_probs = modelo.predict_proba(x_p)
# Nos quedamos unicamente con las predicciones positicas
lr_probs = lr_probs[:, 0]

# %%
yhat = modelo.predict(x_p)

# %%
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import f1_score
from sklearn.metrics import auc

# %%
lr_precision, lr_recall, _ = precision_recall_curve(y_p, lr_probs)
lr_auc =  auc(lr_recall, lr_precision)
no_skill = len(y_p[y_p==1]) / len(y_p)

# %%
print('Redes neuronales: auc=%.3f' % (lr_auc))
pyplot.plot([0, 1], [no_skill, no_skill], linestyle='--', label='Sin entrenar')
pyplot.plot(lr_recall, lr_precision, marker='.', label='Redes Neuronales')
#Etiquetas de ejes
pyplot.xlabel('Sensibilidad')
pyplot.ylabel('Precisión')
pyplot.legend()
mp.grid(True)
pyplot.show()

# %%
modelo.weights
